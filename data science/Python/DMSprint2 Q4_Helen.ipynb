# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import pandas as pd
import numpy as np

# %%
credentials = service_account.Credentials.from_service_account_file('C:/Users/Helen.Tian/Downloads/YETI Google Analytics-45214aca550b.json')# PATH IN YOUR COMPUTER
project_id = 'enduring-hue-184016'   
client = bigquery.Client(credentials= credentials,project=project_id)

# %%
query_job = client.query("""SELECT * FROM `enduring-hue-184016.121992452.results_homepage2`""")
results = query_job.result()
df1 = results.to_dataframe()

# %%
df= pd.read_csv("C:/Users/Helen.Tian/Downloads/Homepage Meta - Sheet1.csv", parse_dates= [0])
df2 = df[['Date','Group Name']].drop_duplicates()

# %%
df1.a_date = pd.to_datetime(df1.a_date)

# %%
timelen = df2.groupby("Group Name")['Date'].count().to_frame().reset_index()

# %%
timelen.sort_values(by=["Date"],ascending=[False])
# Out:
#                     Group Name  Date
# 14          Winter Product Mix    27
# 9        Mother's Day Campaign    24
# 10          Ranch/Rodeo Season    13
# 2            BackFlip Campaign    12
# 3                Camino Launch    12
# 5                  Color Story    11
# 8                   Hopper Two    10
# 11                      Roadie     9
# 0          2017 Year in Review     7
# 4          Charcoal Collection     7
# 6        Father's Day Campaign     7
# 7      Hopper Flip Family Snow     5
# 15       YETI Presents: A Hunt     5
# 13    Tundra/Hopper MAP Change     4
# 1                          BBQ     3
# 12  Summer Launch Announcement     3

# %%
test =pd.merge(df1, df2, how = 'left', left_on = 'a_date', right_on = 'Date')

# %%
test[ (test['b_eventaction']=='add to cart')].head()
# Out:
#          a_date          a_visitorid a_eventcategory a_eventaction  \
# 7294 2018-01-01  2264977358979789976        homepage      main cta
# 7295 2018-01-01  5556243942166102532        homepage      main cta
# 7296 2018-01-01  6573791706851462065        homepage      main cta
# 7297 2018-01-01  4302948570816517317        homepage      main cta
# 7298 2018-01-01  5172293755898356218        homepage      main cta
#
#      b_eventCategory b_eventaction       Date           Group Name
# 7294       ecommerce   add to cart 2018-01-01  2017 Year in Review
# 7295       ecommerce   add to cart 2018-01-01  2017 Year in Review
# 7296       ecommerce   add to cart 2018-01-01  2017 Year in Review
# 7297       ecommerce   add to cart 2018-01-01  2017 Year in Review
# 7298       ecommerce   add to cart 2018-01-01  2017 Year in Review

# %%
test1 = test[['b_eventaction', 'Group Name']]

# %%
########################################################YOUTUBE VIDEO###########################################################

# %%
video = test1[test1.b_eventaction == '100%']

# %%
vi_result = video.groupby('Group Name')['b_eventaction'].count().to_frame().reset_index()

# %%
vi_result['per_day'] = vi_result.b_eventaction/timelen.Date

# %%
vi_result
# Out:
#                     Group Name  b_eventaction    per_day
# 0          2017 Year in Review             79  11.285714
# 1                          BBQ             44  14.666667
# 2            BackFlip Campaign            546  45.500000
# 3                Camino Launch            821  68.416667
# 4          Charcoal Collection             58   8.285714
# 5                  Color Story            673  61.181818
# 6        Father's Day Campaign            116  16.571429
# 7      Hopper Flip Family Snow            311  62.200000
# 8                   Hopper Two            651  65.100000
# 9        Mother's Day Campaign            260  10.833333
# 10          Ranch/Rodeo Season            445  34.230769
# 11                      Roadie            489  54.333333
# 12  Summer Launch Announcement             11   3.666667
# 13    Tundra/Hopper MAP Change            239  59.750000
# 14          Winter Product Mix           2359  87.370370
# 15       YETI Presents: A Hunt            192  38.400000

# %%
vi_result.to_csv("DMsprintQ4plot11.csv")

# %%
########################################################ADD TO CART#############################################################

# %%
cart = test1[test1.b_eventaction == 'add to cart']

# %%
cart
# Out:
#        b_eventaction                  Group Name
# 7294     add to cart         2017 Year in Review
# 7295     add to cart         2017 Year in Review
# 7296     add to cart         2017 Year in Review
# 7297     add to cart         2017 Year in Review
# 7298     add to cart         2017 Year in Review
# 7299     add to cart         2017 Year in Review
# 7300     add to cart         2017 Year in Review
# 7301     add to cart         2017 Year in Review
# 7302     add to cart         2017 Year in Review
# 7303     add to cart         2017 Year in Review
# 7304     add to cart         2017 Year in Review
# 7305     add to cart         2017 Year in Review
# 7306     add to cart         2017 Year in Review
# 7307     add to cart         2017 Year in Review
# 7308     add to cart         2017 Year in Review
# 7309     add to cart         2017 Year in Review
# 7310     add to cart         2017 Year in Review
# 7311     add to cart         2017 Year in Review
# 7312     add to cart         2017 Year in Review
# 7313     add to cart         2017 Year in Review
# 7314     add to cart         2017 Year in Review
# 7315     add to cart         2017 Year in Review
# 7316     add to cart         2017 Year in Review
# 7317     add to cart         2017 Year in Review
# 7318     add to cart         2017 Year in Review
# 7319     add to cart         2017 Year in Review
# 7320     add to cart         2017 Year in Review
# 7321     add to cart         2017 Year in Review
# 7322     add to cart         2017 Year in Review
# 7323     add to cart         2017 Year in Review
# ...              ...                         ...
# 120062   add to cart    Tundra/Hopper MAP Change
# 120063   add to cart    Tundra/Hopper MAP Change
# 120064   add to cart    Tundra/Hopper MAP Change
# 120065   add to cart    Tundra/Hopper MAP Change
# 120066   add to cart    Tundra/Hopper MAP Change
# 120067   add to cart    Tundra/Hopper MAP Change
# 120068   add to cart    Tundra/Hopper MAP Change
# 120069   add to cart    Tundra/Hopper MAP Change
# 120070   add to cart    Tundra/Hopper MAP Change
# 120071   add to cart    Tundra/Hopper MAP Change
# 120072   add to cart    Tundra/Hopper MAP Change
# 120073   add to cart    Tundra/Hopper MAP Change
# 120074   add to cart    Tundra/Hopper MAP Change
# 120075   add to cart    Tundra/Hopper MAP Change
# 120076   add to cart    Tundra/Hopper MAP Change
# 120077   add to cart    Tundra/Hopper MAP Change
# 120078   add to cart    Tundra/Hopper MAP Change
# 120079   add to cart    Tundra/Hopper MAP Change
# 120080   add to cart    Tundra/Hopper MAP Change
# 120081   add to cart    Tundra/Hopper MAP Change
# 120082   add to cart    Tundra/Hopper MAP Change
# 120083   add to cart    Tundra/Hopper MAP Change
# 120084   add to cart           BackFlip Campaign
# 120085   add to cart           BackFlip Campaign
# 120086   add to cart           BackFlip Campaign
# 120087   add to cart  Summer Launch Announcement
# 120088   add to cart  Summer Launch Announcement
# 120089   add to cart  Summer Launch Announcement
# 120090   add to cart  Summer Launch Announcement
# 120091   add to cart  Summer Launch Announcement
#
# [112798 rows x 2 columns]

# %%
ca_result = cart.groupby('Group Name')['b_eventaction'].count().to_frame().reset_index()

# %%
ca_result['per_day'] = ca_result.b_eventaction/timelen.Date

# %%
ca_result
# Out:
#                     Group Name  b_eventaction      per_day
# 0          2017 Year in Review            337    48.142857
# 1                          BBQ            398   132.666667
# 2            BackFlip Campaign           7939   661.583333
# 3                Camino Launch          10802   900.166667
# 4          Charcoal Collection           1371   195.857143
# 5                  Color Story          36162  3287.454545
# 6        Father's Day Campaign           1421   203.000000
# 7      Hopper Flip Family Snow           2543   508.600000
# 8                   Hopper Two           5000   500.000000
# 9        Mother's Day Campaign           4952   206.333333
# 10          Ranch/Rodeo Season           5330   410.000000
# 11                      Roadie           9650  1072.222222
# 12  Summer Launch Announcement            306   102.000000
# 13    Tundra/Hopper MAP Change           3364   841.000000
# 14          Winter Product Mix          22733   841.962963
# 15       YETI Presents: A Hunt            490    98.000000

# %%
ca_result.to_csv("DMsprintQ4plot.csv")

# %%
######################################################## exclude 03/22/2018

# %%
test2=test[(test['a_date']!='2018-03-22') & (test['b_eventaction']=='add to cart')]

# %%
test2
# Out:
#            a_date          a_visitorid              a_eventcategory  \
# 7294   2018-01-01  2264977358979789976                     homepage
# 7295   2018-01-01  5556243942166102532                     homepage
# 7296   2018-01-01  6573791706851462065                     homepage
# 7297   2018-01-01  4302948570816517317                     homepage
# 7298   2018-01-01  5172293755898356218                     homepage
# 7299   2018-01-01  3003464859153222256                     homepage
# 7300   2018-01-01    60174168336063560                     homepage
# 7301   2018-01-01  2909988851639034739                     homepage
# 7302   2018-01-01  3189085382835358813                     homepage
# 7303   2018-01-01  6647544361272414305                     homepage
# 7304   2018-01-01  7163484544724253189                     homepage
# 7305   2018-01-01  8458677377882040330                     homepage
# 7306   2018-01-01  6386005145281039235                     homepage
# 7307   2018-01-01  2204447375559937250                     homepage
# 7308   2018-01-01  8511500106913707742                     homepage
# 7309   2018-01-01  6401052335568688119                     homepage
# 7310   2018-01-01  5970007987518598524                     homepage
# 7311   2018-01-01  7112392876469838422                     homepage
# 7312   2018-01-01  2309780739824729924                     homepage
# 7313   2018-01-01  8836845468723616440                     homepage
# 7314   2018-01-01  2459663892881937607                     homepage
# 7315   2018-01-01  6079773208277081511                     homepage
# 7316   2018-01-01  7899339221368167452                     homepage
# 7317   2018-01-01  1518269454567121423                     homepage
# 7318   2018-01-01   947468103385281548                     homepage
# 7319   2018-01-01  4453177889651342226                     homepage
# 7320   2018-01-01  4453177889651342226                     homepage
# 7321   2018-01-01  4453177889651342226                     homepage
# 7322   2018-01-01  3189085382835358813                     homepage
# 7323   2018-01-01  4550475065162663074                     homepage
# ...           ...                  ...                          ...
# 120062 2018-03-18  8729239654448931076  homepage promotional module
# 120063 2018-03-18  1416089047299467967  homepage promotional module
# 120064 2018-03-18  1416089047299467967  homepage promotional module
# 120065 2018-03-18  3792556956836593207  homepage promotional module
# 120066 2018-03-18  4655224897997274866  homepage promotional module
# 120067 2018-03-18   431217458228715982  homepage promotional module
# 120068 2018-03-18  1416089047299467967  homepage promotional module
# 120069 2018-03-18   533150385199304157  homepage promotional module
# 120070 2018-03-18  4655224897997274866  homepage promotional module
# 120071 2018-03-18  1416089047299467967  homepage promotional module
# 120072 2018-03-18  2326684962258540174  homepage promotional module
# 120073 2018-03-18  6358091182168231463  homepage promotional module
# 120074 2018-03-18  2326684962258540174  homepage promotional module
# 120075 2018-03-18  1247478883342079324  homepage promotional module
# 120076 2018-03-18  2146204354851947567  homepage promotional module
# 120077 2018-03-18  6358091182168231463  homepage promotional module
# 120078 2018-03-18  7866388236577418389  homepage promotional module
# 120079 2018-03-18  9182723024777837330  homepage promotional module
# 120080 2018-03-18  7578663343711963149  homepage promotional module
# 120081 2018-03-18  1247478883342079324  homepage promotional module
# 120082 2018-03-18  6200419157455847199  homepage promotional module
# 120083 2018-03-18   431217458228715982  homepage promotional module
# 120084 2018-03-19  6992618015411965596  homepage promotional module
# 120085 2018-03-19  6992618015411965596  homepage promotional module
# 120086 2018-03-19  7955793826297113150  homepage promotional module
# 120087 2018-05-31  3843732613161258669  homepage promotional module
# 120088 2018-05-31  3843732613161258669  homepage promotional module
# 120089 2018-05-31  3843732613161258669  homepage promotional module
# 120090 2018-05-31  7241610798715170541  homepage promotional module
# 120091 2018-05-31  3843732613161258669  homepage promotional module
#
#            a_eventaction b_eventCategory b_eventaction       Date  \
# 7294            main cta       ecommerce   add to cart 2018-01-01
# 7295            main cta       ecommerce   add to cart 2018-01-01
# 7296            main cta       ecommerce   add to cart 2018-01-01
# 7297            main cta       ecommerce   add to cart 2018-01-01
# 7298            main cta       ecommerce   add to cart 2018-01-01
# 7299            main cta       ecommerce   add to cart 2018-01-01
# 7300            main cta       ecommerce   add to cart 2018-01-01
# 7301            main cta       ecommerce   add to cart 2018-01-01
# 7302            main cta       ecommerce   add to cart 2018-01-01
# 7303            main cta       ecommerce   add to cart 2018-01-01
# 7304            main cta       ecommerce   add to cart 2018-01-01
# 7305            main cta       ecommerce   add to cart 2018-01-01
# 7306            main cta       ecommerce   add to cart 2018-01-01
# 7307            main cta       ecommerce   add to cart 2018-01-01
# 7308            main cta       ecommerce   add to cart 2018-01-01
# 7309            main cta       ecommerce   add to cart 2018-01-01
# 7310            main cta       ecommerce   add to cart 2018-01-01
# 7311            main cta       ecommerce   add to cart 2018-01-01
# 7312            main cta       ecommerce   add to cart 2018-01-01
# 7313            main cta       ecommerce   add to cart 2018-01-01
# 7314            main cta       ecommerce   add to cart 2018-01-01
# 7315            main cta       ecommerce   add to cart 2018-01-01
# 7316            main cta       ecommerce   add to cart 2018-01-01
# 7317            main cta       ecommerce   add to cart 2018-01-01
# 7318            main cta       ecommerce   add to cart 2018-01-01
# 7319            main cta       ecommerce   add to cart 2018-01-01
# 7320            main cta       ecommerce   add to cart 2018-01-01
# 7321            main cta       ecommerce   add to cart 2018-01-01
# 7322            main cta       ecommerce   add to cart 2018-01-01
# 7323            main cta       ecommerce   add to cart 2018-01-01
# ...                  ...             ...           ...        ...
# 120062  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120063  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120064  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120065  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120066  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120067  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120068  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120069  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120070  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120071  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120072  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120073  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120074  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120075  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120076  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120077  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120078  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120079  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120080  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120081  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120082  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120083  column 2 / row 2       ecommerce   add to cart 2018-03-18
# 120084  column 2 / row 2       ecommerce   add to cart 2018-03-19
# 120085  column 2 / row 2       ecommerce   add to cart 2018-03-19
# 120086  column 2 / row 2       ecommerce   add to cart 2018-03-19
# 120087  column 2 / row 2       ecommerce   add to cart 2018-05-31
# 120088  column 2 / row 2       ecommerce   add to cart 2018-05-31
# 120089  column 2 / row 2       ecommerce   add to cart 2018-05-31
# 120090  column 2 / row 2       ecommerce   add to cart 2018-05-31
# 120091  column 2 / row 2       ecommerce   add to cart 2018-05-31
#
#                         Group Name
# 7294           2017 Year in Review
# 7295           2017 Year in Review
# 7296           2017 Year in Review
# 7297           2017 Year in Review
# 7298           2017 Year in Review
# 7299           2017 Year in Review
# 7300           2017 Year in Review
# 7301           2017 Year in Review
# 7302           2017 Year in Review
# 7303           2017 Year in Review
# 7304           2017 Year in Review
# 7305           2017 Year in Review
# 7306           2017 Year in Review
# 7307           2017 Year in Review
# 7308           2017 Year in Review
# 7309           2017 Year in Review
# 7310           2017 Year in Review
# 7311           2017 Year in Review
# 7312           2017 Year in Review
# 7313           2017 Year in Review
# 7314           2017 Year in Review
# 7315           2017 Year in Review
# 7316           2017 Year in Review
# 7317           2017 Year in Review
# 7318           2017 Year in Review
# 7319           2017 Year in Review
# 7320           2017 Year in Review
# 7321           2017 Year in Review
# 7322           2017 Year in Review
# 7323           2017 Year in Review
# ...                            ...
# 120062    Tundra/Hopper MAP Change
# 120063    Tundra/Hopper MAP Change
# 120064    Tundra/Hopper MAP Change
# 120065    Tundra/Hopper MAP Change
# 120066    Tundra/Hopper MAP Change
# 120067    Tundra/Hopper MAP Change
# 120068    Tundra/Hopper MAP Change
# 120069    Tundra/Hopper MAP Change
# 120070    Tundra/Hopper MAP Change
# 120071    Tundra/Hopper MAP Change
# 120072    Tundra/Hopper MAP Change
# 120073    Tundra/Hopper MAP Change
# 120074    Tundra/Hopper MAP Change
# 120075    Tundra/Hopper MAP Change
# 120076    Tundra/Hopper MAP Change
# 120077    Tundra/Hopper MAP Change
# 120078    Tundra/Hopper MAP Change
# 120079    Tundra/Hopper MAP Change
# 120080    Tundra/Hopper MAP Change
# 120081    Tundra/Hopper MAP Change
# 120082    Tundra/Hopper MAP Change
# 120083    Tundra/Hopper MAP Change
# 120084           BackFlip Campaign
# 120085           BackFlip Campaign
# 120086           BackFlip Campaign
# 120087  Summer Launch Announcement
# 120088  Summer Launch Announcement
# 120089  Summer Launch Announcement
# 120090  Summer Launch Announcement
# 120091  Summer Launch Announcement
#
# [101861 rows x 8 columns]

# %%
test2_result = test2.groupby('Group Name')['b_eventaction'].count().to_frame().reset_index()

# %%
test2_result
# Out:
#                     Group Name  b_eventaction
# 0          2017 Year in Review            337
# 1                          BBQ            398
# 2            BackFlip Campaign           7939
# 3                Camino Launch          10802
# 4          Charcoal Collection           1371
# 5                  Color Story          25225
# 6        Father's Day Campaign           1421
# 7      Hopper Flip Family Snow           2543
# 8                   Hopper Two           5000
# 9        Mother's Day Campaign           4952
# 10          Ranch/Rodeo Season           5330
# 11                      Roadie           9650
# 12  Summer Launch Announcement            306
# 13    Tundra/Hopper MAP Change           3364
# 14          Winter Product Mix          22733
# 15       YETI Presents: A Hunt            490

# %%
test2_result['per_day'] = test2_result.b_eventaction/timelen.Date

# %%
test2_result
# Out:
#                     Group Name  b_eventaction      per_day
# 0          2017 Year in Review            337    48.142857
# 1                          BBQ            398   132.666667
# 2            BackFlip Campaign           7939   661.583333
# 3                Camino Launch          10802   900.166667
# 4          Charcoal Collection           1371   195.857143
# 5                  Color Story          25225  2293.181818
# 6        Father's Day Campaign           1421   203.000000
# 7      Hopper Flip Family Snow           2543   508.600000
# 8                   Hopper Two           5000   500.000000
# 9        Mother's Day Campaign           4952   206.333333
# 10          Ranch/Rodeo Season           5330   410.000000
# 11                      Roadie           9650  1072.222222
# 12  Summer Launch Announcement            306   102.000000
# 13    Tundra/Hopper MAP Change           3364   841.000000
# 14          Winter Product Mix          22733   841.962963
# 15       YETI Presents: A Hunt            490    98.000000
