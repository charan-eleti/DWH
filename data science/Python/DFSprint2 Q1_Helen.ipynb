# %%
import pandas as pd
import numpy as np
import pyodbc  
from datetime import datetime 
import matplotlib.pylab as plt
from sklearn.cluster import KMeans

# %%
conn = pyodbc.connect("Driver={ODBC Driver 13 for SQL Server};Server=yetidb01.database.windows.net;database=YETISQLDW01;uid=htian;PWD=HeLeNtIAn52!")
cursor = conn.cursor()

# %%
df = pd.read_sql("SELECT [Sold_to_Party_Name] ,[ShipToPartyAddress] FROM [EDW].[sap_zva05_fct] where (SalesOffice='STD' or SalesOffice='HYB') ", conn)

# %%
df=df.drop_duplicates()

# %%
df1 = df.groupby('Sold_to_Party_Name')['ShipToPartyAddress'].count().to_frame().reset_index()

# %%
df2 =df1.sort_values(by=["ShipToPartyAddress"],ascending=[False])

# %%
df2
# Out:
#                     Sold_to_Party_Name  ShipToPartyAddress
# 2408                               GSA                 561
# 1235                         Cavenders                 213
# 6593                Whole Foods Market                 195
# 4568          Pacific Flyway Wholesale                 188
# 5206                 Rural King Supply                 133
# 6552             Westlake Ace Hardware                 114
# 797              Blains Supply Company                  87
# 5335                           Scheels                  83
# 4127                  Mills Fleet Farm                  78
# 5879                               TJX                  74
# 1408              Coast Guard Exchange                  71
# 4275              NASD - April Stevens                  68
# 5819        Sunbelt Rentals - Angleton                  66
# 4580                     Palmetto Moon                  65
# 3542                         L.L. Bean                  59
# 4258      Murdochs Ranch & Home Supply                  59
# 5845      Surf Style Retail Management                  52
# 3905             Marine Corps Exchange                  50
# 1425                           Coburns                  46
# 5170                 Ron Jon Surf Shop                  45
# 881          Boot Barn Inc - Corporate                  43
# 754                    Big R Warehouse                  43
# 3951                      Marvins CNRG                  40
# 2072  Everglades Farm Equipment Co Inc                  40
# 6264      Turkey Shoppe on Main - NWTF                  40
# 5205               Runnings Supply Inc                  40
# 96                        Ace Hardware                  35
# 2620          Great Lakes Ace Hardware                  35
# 6600                 Wilco Farmers Inc                  35
# 5751                      Stine Lumber                  33
# ...                                ...                 ...
# 4079                  Michael Herrmann                   1
# 1762                    Debbie Bachman                   1
# 4059         Merrillville Ace Hardware                   1
# 1761    Deatons Building & Home Center                   1
# 4047                      Melville Ace                   1
# 4048                     Memory Makers                   1
# 4049                   Mena Pawn & Gun                   1
# 1760                   Deanna Orillion                   1
# 4052            Mendo Mill - Clearlake                   1
# 4053               Mequon Ace Hardware                   1
# 1756                DeLand Motorsports                   1
# 4055          Mercedes Benz of Spokane                   1
# 4056           Merickel Lumber Inc Ace                   1
# 1754               DeGroods Home Store                   1
# 4058              Merrill Ace Hardware                   1
# 4060                      Mesa Tractor                   1
# 4078                 Michael Gillespie                   1
# 4061          Mesquite Lumber & Supply                   1
# 1749                      Dawn Jerulle                   1
# 1747              Davis Sport Shop Inc                   1
# 1744                  Davie Outfitters                   1
# 4069               Mexico Beach Marina                   1
# 1743     Davidson River Outfitters Inc                   1
# 1742            Davidson College Store                   1
# 4072                Miacomet Golf Club                   1
# 4074                   Michael Baldwin                   1
# 4075                    Michael Carter                   1
# 4076              Michael David Winery                   1
# 4077                      Michael Debi                   1
# 6756                       uppel patel                   1
#
# [6757 rows x 2 columns]

# %%
len(df2)
# Out:
# 6750

# %%
q=[0]*4
for num in df2.ShipToPartyAddress:
    if num>100:   # >100
       q[0]+=1
    elif num>10 : # 11-100
       q[1]+=1
    elif num>5 :  # 3-10
       q[2]+=1
    else:         # 1-2
       q[3]+=1

# %%
q
# Out:
# [6, 174, 345, 6225]
